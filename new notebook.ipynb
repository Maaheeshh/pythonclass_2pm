# %%
from bs4 import BeautifulSoup
import requests
for i in range(1,6):
    url = BeautifulSoup(f'http://nepalstock.com/main/todays_price/index/1/{i}/', 'html.parser')
    soup=requests.get(url)
    soup
# Out:
# C:\Users\HP\anaconda\lib\site-packages\bs4\__init__.py:431: MarkupResemblesLocatorWarning: "http://nepalstock.com/main/todays_price/index/1/1/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ...

# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://merolagani.com/LatestMarket.aspx', 'html.parser')
soup=requests.get(url)
soup
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
code=soup.text    #beautiful code parse garna mildaina     lxml brouser readble format
code

# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup(f'https://merolagani.com/LatestMarket.aspx', 'html.parser')
soup=requests.get(url)
soup
# Out:
# <Response [200]>

# %%
lxml_code=BeautifulSoup(code, "lxml")    #browser readle form
lxml_code
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>
# 	merolagani - Nepal Stock Exchange (NEPSE) Live Trading Data, Live Floorsheet, Live Indices, Top Gainers, Top Losers
# </title><link href="/bundles/css/main200?v=XBmv3Nbj66DV6lzAxQCBgaIOrn903Diuut8lsSb3n9k1" rel="stylesheet"/>
# <link href="/bundles/css/site205?v=XfpTpb13QleC-1jczI-2fcsVnZZwOVdhr5NbHe2WGYI1" rel="stylesheet"/>
# <link href="/Content/Services.css" rel="stylesheet"/>
# <link href="/Content/owl.carousel.min.css" rel="stylesheet"/>
# <link href="/Content/lightslider/css/lightslider.css" rel="stylesheet"/>
# <script src="/scripts/jquery/jquery-1.11.0.min.js"></script>
# <script src="/scripts/jquery/jquery-ui.js"></script>
# <script src="/Content/lightslider/js/lightslider.js"></script>
# <!--[if lt IE 9]>
# ...

# %%
table=lxml_code.table

# %%
header_tag=required_table.find_all('th')
print(header_ta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8716/1403628709.py in <module>
# ----> 1 header_tag=required_table.find_all('th')
#       2 print(header_ta)
#
# NameError: name 'required_table' is not defined

# %%
tag=table.find_all('tr')
tag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8716/2427106240.py in <module>
# ----> 1 tag=table.find_all('tr')
#       2 tag
#
# NameError: name 'table' is not defined

# %%
for i in range(len(tag)):    #sabai ko value nikalana range use gariyo  list ko format ma ayo sabai data
    print(tag[i].text.split('\n')[1:-1])
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
tag=table.find_all('tr')    #list ko form ma ayera baseko xa
tag
# Out:
# [<tr><th><span>Symbol</span></th><th><span>LTP</span></th><th nowrap=""><span>% Change</span></th><th><span>Open</span></th><th><span>High</span></th><th><span>Low</span></th><th><span>Qty.</span></th><th><span>PClose</span></th><th><span>Diff.</span></th><th></th><th></th></tr>,
#  <tr class="decrease-row"><td><a href="/CompanyDetail.aspx?symbol=ACLBSL" target="_blank" title="ACLBSL (Aarambha Chautari Laghubitta Bittiya Sanstha Limited)">ACLBSL</a></td><td class="text-right">830.00</td><td class="text-right">-1.78</td><td class="text-right">833.00</td><td class="text-right">820.00</td><td class="text-right">832.00</td><td class="text-right">721</td><td><a href="javascript:void(0);" onclick='addToWatchlist("ACLBSL");' title="Add to Watchlist"><i class="icon-tags icon-white"></i></a></td><td><a href="javascript:void(0);" onclick='setAlert("ACLBSL");' title="Set as Alert"><i class="icon-bell icon-white"></i></a></td></tr>,
# ...

# %%
tag[0].text.split('\n')
# Out:
# ['SymbolLTP% ChangeOpenHighLowQty.PCloseDiff.']

# %%
output=[]
for i in range(len(tag)):    
    datas=tag[i].text.split(',')
    if datas!=',':
        output.append(datas)
output
# Out:
# [['\n\nAs of 2022-06-03\xa015:00:00\n\n Select Date\n                    \n\n\n\nStock Symbol\... ...  |\n                \nTotal Rows\n                    \n20\n50\n200\n300\n500\n |\n                \n\n\nExport\n\n\n'],
#  ['\nS.N.\nTraded Companies\nNo. Of Transaction\nMax Price\nMin Price\nClosing Price\nTraded Shares\nAmount\nPrevious Closing\nDifference Rs.\n'],
#  ['\n1\n11% NIC Asia Debenture 082/83\n2\n998.00\n998.00\n998.00\n160.00\n159680.00\n999.00\n-1.00\xa0\n                                             \n\n'],
#  ['\n2\n12 % Goodwill Finance Limited Debenture 2083\n2\n1070.10\n1070.00\n1070.10\n35.00\n37451.00\n1071.10\n-1.00\xa0\n                                             \n\n'],
#  ['\n3\n12% ICFC Finance Limited Debenture 2083\n2\n1070.00\n1070.00\n1070.00\n100.00\n107000.00\n1070.00\n0.00\xa0\n                                            \n\n'],
# ...

# %%
import csv 
file=open('nepsepr12.csv','w')
x=csv.writer(file)

# for i in output:
#     x.writerow(i)

# %%
import pandas as pd
df=pd.read_csv('nepsepr12.csv')
df
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3348/4035618353.py in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('nepsepr12.csv')
#       3 df
#
# ~\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from bs4 import BeautifulSoup
import requests
for i in range(1,6):
    url = BeautifulSoup(f'http://nepalstock.com/main/todays_price/index/1/{i}/', 'html.parser')
    soup=requests.get(url)
    soup

# %%
import plotly.graph_objects as go

fig = go.Figure([go.Bar(x=qty, y=Change)])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3348/951231841.py in <module>
#       1 import plotly.graph_objects as go
#       2
# ----> 3 fig = go.Figure([go.Bar(x=qty, y=Change)])
#       4 fig.show()
#
# NameError: name 'qty' is not defined

# %%
import requests as r
from bs4 import BeautifulSoup
reponse=r.get('https://merolagani.com/LatestMarket.aspx')
share_text=respone.text
soup=BeautifulSoup(share_text,'html,parser')
soup
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
print(soup.title)

# %%
print(soup.a)

# %%
print(soup.find('a'))

# %%
print(len(soup.find_all('a')))

# %%
print(len(soup.find_all('table')))
